# %% [markdown]
# Numpy:library
# 10 to 1000 times

# %%
pip install numpy
# Out:
# ...
#   Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl (12.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.4.6

# %%
name = np.array(["jony","may","julye"])
name
# Out:
# array(['jony', 'may', 'julye'], dtype='<U5')

# %%
name.dtype
# Out:
# dtype('<U5')

# %%
number1 = np.array([5])
number1
# Out:
# array([5])

# %%
from statistics import mode,mean,median

data = np.array([[78,89,45],[45,90,45]])
data.ndim
# Out:
# 2

# %%
np.mean(data)
# Out:
# np.float64(65.33333333333333)

# %%
values,counts = np.unique(data,return_counts=True)
mode = values[np.argmax(counts)]
print(mode)
print(values)
print(counts)
# Out:
# 45
# [45 78 89 90]
# [3 1 1 1]

# %%
# indexing of 1-d
import numpy as np
numdata = np.array([13,56,78,23])
print(numdata[0])
print(np.random.randint(10000))
# Out:
# 13
# 3868

# %%
print(numdata[3])
numdata = np.array([13,56,78,23])
print(numdata[-1])
#first value
print(numdata[0])

np.mean(numdata)
np.median(numdata)
# Out:
# 23
# 23
# 13
# np.float64(39.5)

# %%
numdata2 = np.array([[10,20,30],[40,50,60],[70,80,90]])
numdata2.ndim
numdata2[0,0]
numdata2[1,1]
#row1
numdata2[0]
#colum2
numdata2[:,0]
# Out:
# array([10, 40, 70])

# %%
numdata2 = np.array([[10,20,30],[40,50,60],[70,80,90]])
numdata2[1:3,1:3]
# Out:
# array([[50, 60],
#        [80, 90]])
